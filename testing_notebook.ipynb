# %% [markdown]
# # Testing the functions work correctly

# %%
import pickle5
from phynteny_utils import train_model
from phynteny_utils import format_data
import numpy as np

# %%
from importlib import reload
reload(train_model)
reload(format_data)
# Out:
# <module 'phynteny_utils.format_data' from '/Users/susiegrigson/PycharmProjects/Phynteny/phynteny_utils/format_data.py'>

# %%
prophage_dict =pickle5.load(open('test_data/test_training_data.pkl', 'rb'))
subset_keys = list(prophage_dict.keys())
subset_dict = dict(zip(subset_keys, [prophage_dict.get(i) for i in subset_keys]))

# %%
hyperparameters = {'neurons': [10, 20, 30], "dropout": [0.1, 0.2]}
train_model.random_search('test_data/test_training_data.pkl', hyperparameters,num_trials=3, epochs=5)
# Out:
# /Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=10.
#   warnings.warn(
# layer: 0
# Model: "sequential_173"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_346 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_347 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_173 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.37343, saving model to model_0best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.05556, saving model to model_0best_val_loss.h5
# 3/3 - 3s - loss: 2.4900 - accuracy: 0.0317 - val_loss: 2.3734 - val_accuracy: 0.0556 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.37343 to 2.20447, saving model to model_0best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.05556 to 0.16111, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 2.3229 - accuracy: 0.0660 - val_loss: 2.2045 - val_accuracy: 0.1611 - 191ms/epoch - 64ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.20447 to 2.03444, saving model to model_0best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.16111 to 0.81667, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 2.1650 - accuracy: 0.3120 - val_loss: 2.0344 - val_accuracy: 0.8167 - 188ms/epoch - 63ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.03444 to 1.84851, saving model to model_0best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.81667 to 0.85833, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 2.0025 - accuracy: 0.7786 - val_loss: 1.8485 - val_accuracy: 0.8583 - 185ms/epoch - 62ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.84851 to 1.63887, saving model to model_0best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.85833 to 0.87222, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 1.8253 - accuracy: 0.8162 - val_loss: 1.6389 - val_accuracy: 0.8722 - 186ms/epoch - 62ms/step
# layer: 0
# Model: "sequential_174"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_348 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_349 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_174 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.10597, saving model to model_1best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.49537, saving model to model_1best_val_loss.h5
# 3/3 - 3s - loss: 2.2321 - accuracy: 0.0978 - val_loss: 2.1060 - val_accuracy: 0.4954 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.10597 to 1.94328, saving model to model_1best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.49537 to 0.81574, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 2.0661 - accuracy: 0.6765 - val_loss: 1.9433 - val_accuracy: 0.8157 - 188ms/epoch - 63ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.94328 to 1.76839, saving model to model_1best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.81574 to 0.82407, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 1.8985 - accuracy: 0.8336 - val_loss: 1.7684 - val_accuracy: 0.8241 - 187ms/epoch - 62ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.76839 to 1.57479, saving model to model_1best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.82407
# 3/3 - 0s - loss: 1.7105 - accuracy: 0.8424 - val_loss: 1.5748 - val_accuracy: 0.8241 - 167ms/epoch - 56ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.57479 to 1.36793, saving model to model_1best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.82407
# 3/3 - 0s - loss: 1.5004 - accuracy: 0.8425 - val_loss: 1.3679 - val_accuracy: 0.8241 - 166ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_175"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_350 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_351 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_175 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.27926, saving model to model_2best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.02407, saving model to model_2best_val_loss.h5
# 3/3 - 3s - loss: 2.3983 - accuracy: 0.0152 - val_loss: 2.2793 - val_accuracy: 0.0241 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.27926 to 2.11726, saving model to model_2best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.02407 to 0.18704, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 2.2231 - accuracy: 0.0724 - val_loss: 2.1173 - val_accuracy: 0.1870 - 184ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.11726 to 1.95698, saving model to model_2best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.18704 to 0.67685, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 2.0584 - accuracy: 0.2652 - val_loss: 1.9570 - val_accuracy: 0.6769 - 185ms/epoch - 62ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.95698 to 1.79218, saving model to model_2best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.67685 to 0.77963, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 1.8929 - accuracy: 0.7423 - val_loss: 1.7922 - val_accuracy: 0.7796 - 181ms/epoch - 60ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.79218 to 1.61926, saving model to model_2best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.77963 to 0.80648, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 1.7214 - accuracy: 0.8031 - val_loss: 1.6193 - val_accuracy: 0.8065 - 179ms/epoch - 60ms/step
# layer: 0
# Model: "sequential_176"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_352 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_353 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_176 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.12361, saving model to model_3best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.07593, saving model to model_3best_val_loss.h5
# 3/3 - 3s - loss: 2.2535 - accuracy: 0.0457 - val_loss: 2.1236 - val_accuracy: 0.0759 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.12361 to 1.94789, saving model to model_3best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.07593 to 0.81481, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 2.0672 - accuracy: 0.5600 - val_loss: 1.9479 - val_accuracy: 0.8148 - 182ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.94789 to 1.77442, saving model to model_3best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.81481 to 0.81944, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.8915 - accuracy: 0.8320 - val_loss: 1.7744 - val_accuracy: 0.8194 - 182ms/epoch - 61ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.77442 to 1.59380, saving model to model_3best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.81944
# 3/3 - 0s - loss: 1.7124 - accuracy: 0.8418 - val_loss: 1.5938 - val_accuracy: 0.8139 - 165ms/epoch - 55ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.59380 to 1.40178, saving model to model_3best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.81944
# 3/3 - 0s - loss: 1.5253 - accuracy: 0.8435 - val_loss: 1.4018 - val_accuracy: 0.8139 - 164ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_177"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_354 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_355 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_177 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.03545, saving model to model_4best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.85463, saving model to model_4best_val_loss.h5
# 3/3 - 3s - loss: 2.2133 - accuracy: 0.1877 - val_loss: 2.0355 - val_accuracy: 0.8546 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.03545 to 1.79919, saving model to model_4best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.85463 to 0.86019, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 1.9862 - accuracy: 0.8119 - val_loss: 1.7992 - val_accuracy: 0.8602 - 182ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.79919 to 1.56363, saving model to model_4best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.86019 to 0.86296, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 1.7661 - accuracy: 0.8311 - val_loss: 1.5636 - val_accuracy: 0.8630 - 184ms/epoch - 61ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.56363 to 1.33015, saving model to model_4best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.86296 to 0.86389, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 1.5435 - accuracy: 0.8369 - val_loss: 1.3301 - val_accuracy: 0.8639 - 185ms/epoch - 62ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.33015 to 1.10979, saving model to model_4best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.86389
# 3/3 - 0s - loss: 1.3241 - accuracy: 0.8380 - val_loss: 1.1098 - val_accuracy: 0.8639 - 164ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_178"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_356 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_357 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_178 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.07301, saving model to model_5best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.62037, saving model to model_5best_val_loss.h5
# 3/3 - 3s - loss: 2.1853 - accuracy: 0.4731 - val_loss: 2.0730 - val_accuracy: 0.6204 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.07301 to 1.87432, saving model to model_5best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.62037 to 0.74537, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.9923 - accuracy: 0.7469 - val_loss: 1.8743 - val_accuracy: 0.7454 - 184ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.87432 to 1.65834, saving model to model_5best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.74537 to 0.79722, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.7832 - accuracy: 0.8085 - val_loss: 1.6583 - val_accuracy: 0.7972 - 184ms/epoch - 61ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.65834 to 1.43043, saving model to model_5best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.79722 to 0.81759, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.5562 - accuracy: 0.8353 - val_loss: 1.4304 - val_accuracy: 0.8176 - 180ms/epoch - 60ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.43043 to 1.20443, saving model to model_5best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.81759 to 0.82500, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.3216 - accuracy: 0.8406 - val_loss: 1.2044 - val_accuracy: 0.8250 - 181ms/epoch - 60ms/step
# layer: 0
# Model: "sequential_179"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_358 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_359 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_179 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.05603, saving model to model_6best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.66204, saving model to model_6best_val_loss.h5
# 3/3 - 3s - loss: 2.1751 - accuracy: 0.3996 - val_loss: 2.0560 - val_accuracy: 0.6620 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.05603 to 1.84045, saving model to model_6best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.66204 to 0.71296, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 1.9561 - accuracy: 0.7596 - val_loss: 1.8405 - val_accuracy: 0.7130 - 195ms/epoch - 65ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.84045 to 1.61524, saving model to model_6best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.71296 to 0.77222, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 1.7259 - accuracy: 0.7818 - val_loss: 1.6152 - val_accuracy: 0.7722 - 191ms/epoch - 64ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.61524 to 1.39063, saving model to model_6best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.77222 to 0.80926, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 1.4882 - accuracy: 0.8122 - val_loss: 1.3906 - val_accuracy: 0.8093 - 191ms/epoch - 64ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.39063 to 1.18810, saving model to model_6best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.80926
# 3/3 - 0s - loss: 1.2543 - accuracy: 0.8298 - val_loss: 1.1881 - val_accuracy: 0.8093 - 166ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_180"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_360 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_361 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_180 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.04148, saving model to model_7best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.79907, saving model to model_7best_val_loss.h5
# 3/3 - 3s - loss: 2.2138 - accuracy: 0.5407 - val_loss: 2.0415 - val_accuracy: 0.7991 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.04148 to 1.82971, saving model to model_7best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.79907 to 0.84259, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 2.0218 - accuracy: 0.7531 - val_loss: 1.8297 - val_accuracy: 0.8426 - 182ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.82971 to 1.61438, saving model to model_7best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.84259 to 0.85278, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 1.8141 - accuracy: 0.7921 - val_loss: 1.6144 - val_accuracy: 0.8528 - 182ms/epoch - 61ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.61438 to 1.38946, saving model to model_7best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.85278
# 3/3 - 0s - loss: 1.6024 - accuracy: 0.8225 - val_loss: 1.3895 - val_accuracy: 0.8491 - 164ms/epoch - 55ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.38946 to 1.16167, saving model to model_7best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.85278
# 3/3 - 0s - loss: 1.3802 - accuracy: 0.8380 - val_loss: 1.1617 - val_accuracy: 0.8500 - 162ms/epoch - 54ms/step
# layer: 0
# Model: "sequential_181"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_362 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_363 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_181 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.02964, saving model to model_8best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.80370, saving model to model_8best_val_loss.h5
# 3/3 - 3s - loss: 2.1765 - accuracy: 0.6366 - val_loss: 2.0296 - val_accuracy: 0.8037 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.02964 to 1.83776, saving model to model_8best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.80370 to 0.83981, saving model to model_8best_val_loss.h5
# 3/3 - 0s - loss: 1.9963 - accuracy: 0.7861 - val_loss: 1.8378 - val_accuracy: 0.8398 - 188ms/epoch - 63ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.83776 to 1.62884, saving model to model_8best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.83981 to 0.84352, saving model to model_8best_val_loss.h5
# 3/3 - 0s - loss: 1.8003 - accuracy: 0.8220 - val_loss: 1.6288 - val_accuracy: 0.8435 - 188ms/epoch - 63ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.62884 to 1.40049, saving model to model_8best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.84352
# 3/3 - 0s - loss: 1.5882 - accuracy: 0.8314 - val_loss: 1.4005 - val_accuracy: 0.8389 - 167ms/epoch - 56ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.40049 to 1.17182, saving model to model_8best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.84352
# 3/3 - 0s - loss: 1.3633 - accuracy: 0.8369 - val_loss: 1.1718 - val_accuracy: 0.8407 - 170ms/epoch - 57ms/step
# layer: 0
# Model: "sequential_182"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_364 (Bidirect  (None, 120, 40)          5920
#  ional)
#
#  bidirectional_365 (Bidirect  (None, 120, 40)          9760
#  ional)
#
#  time_distributed_182 (TimeD  (None, 120, 10)          410
#  istributed)
#
# =================================================================
# Total params: 16,090
# Trainable params: 16,090
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.27553, saving model to model_9best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.01574, saving model to model_9best_val_loss.h5
# 3/3 - 3s - loss: 2.4106 - accuracy: 0.0246 - val_loss: 2.2755 - val_accuracy: 0.0157 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.27553 to 2.08051, saving model to model_9best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.01574 to 0.72130, saving model to model_9best_val_loss.h5
# 3/3 - 0s - loss: 2.2278 - accuracy: 0.2830 - val_loss: 2.0805 - val_accuracy: 0.7213 - 183ms/epoch - 61ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.08051 to 1.87746, saving model to model_9best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.72130 to 0.75741, saving model to model_9best_val_loss.h5
# 3/3 - 0s - loss: 2.0455 - accuracy: 0.6720 - val_loss: 1.8775 - val_accuracy: 0.7574 - 183ms/epoch - 61ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.87746 to 1.65651, saving model to model_9best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.75741 to 0.79259, saving model to model_9best_val_loss.h5
# 3/3 - 0s - loss: 1.8522 - accuracy: 0.7083 - val_loss: 1.6565 - val_accuracy: 0.7926 - 189ms/epoch - 63ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.65651 to 1.41506, saving model to model_9best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.79259 to 0.85463, saving model to model_9best_val_loss.h5
# 3/3 - 0s - loss: 1.6394 - accuracy: 0.7610 - val_loss: 1.4151 - val_accuracy: 0.8546 - 185ms/epoch - 62ms/step
# /Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   warnings.warn(
# layer: 0
# Model: "sequential_183"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_366 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_367 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_183 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.13441, saving model to model_0best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.58148, saving model to model_0best_val_loss.h5
# 3/3 - 3s - loss: 2.2013 - accuracy: 0.1895 - val_loss: 2.1344 - val_accuracy: 0.5815 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.13441 to 2.05734, saving model to model_0best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.58148 to 0.64444, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 2.1194 - accuracy: 0.5787 - val_loss: 2.0573 - val_accuracy: 0.6444 - 166ms/epoch - 55ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.05734 to 1.97636, saving model to model_0best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.64444 to 0.68611, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 2.0383 - accuracy: 0.6872 - val_loss: 1.9764 - val_accuracy: 0.6861 - 170ms/epoch - 57ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.97636 to 1.88956, saving model to model_0best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.68611 to 0.71204, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 1.9527 - accuracy: 0.7250 - val_loss: 1.8896 - val_accuracy: 0.7120 - 169ms/epoch - 56ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.88956 to 1.79517, saving model to model_0best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.71204 to 0.72407, saving model to model_0best_val_loss.h5
# 3/3 - 0s - loss: 1.8610 - accuracy: 0.7447 - val_loss: 1.7952 - val_accuracy: 0.7241 - 166ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_184"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_368 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_369 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_184 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.17378, saving model to model_1best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.58704, saving model to model_1best_val_loss.h5
# 3/3 - 3s - loss: 2.2416 - accuracy: 0.4025 - val_loss: 2.1738 - val_accuracy: 0.5870 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.17378 to 2.10012, saving model to model_1best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.58704 to 0.62593, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 2.1684 - accuracy: 0.6847 - val_loss: 2.1001 - val_accuracy: 0.6259 - 169ms/epoch - 56ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.10012 to 2.02205, saving model to model_1best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.62593 to 0.66667, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 2.0875 - accuracy: 0.7094 - val_loss: 2.0221 - val_accuracy: 0.6667 - 163ms/epoch - 54ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.02205 to 1.93846, saving model to model_1best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.66667 to 0.70926, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 2.0030 - accuracy: 0.7354 - val_loss: 1.9385 - val_accuracy: 0.7093 - 169ms/epoch - 56ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.93846 to 1.84879, saving model to model_1best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.70926 to 0.74537, saving model to model_1best_val_loss.h5
# 3/3 - 0s - loss: 1.9115 - accuracy: 0.7499 - val_loss: 1.8488 - val_accuracy: 0.7454 - 169ms/epoch - 56ms/step
# layer: 0
# Model: "sequential_185"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_370 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_371 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_185 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.15407, saving model to model_2best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.03333, saving model to model_2best_val_loss.h5
# 3/3 - 3s - loss: 2.2122 - accuracy: 0.0478 - val_loss: 2.1541 - val_accuracy: 0.0333 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.15407 to 2.08113, saving model to model_2best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.03333 to 0.67037, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 2.1447 - accuracy: 0.1940 - val_loss: 2.0811 - val_accuracy: 0.6704 - 166ms/epoch - 55ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.08113 to 2.00840, saving model to model_2best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.67037 to 0.80833, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 2.0754 - accuracy: 0.6311 - val_loss: 2.0084 - val_accuracy: 0.8083 - 165ms/epoch - 55ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.00840 to 1.93321, saving model to model_2best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.80833 to 0.82037, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 2.0066 - accuracy: 0.7569 - val_loss: 1.9332 - val_accuracy: 0.8204 - 164ms/epoch - 55ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.93321 to 1.85304, saving model to model_2best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.82037 to 0.82685, saving model to model_2best_val_loss.h5
# 3/3 - 0s - loss: 1.9346 - accuracy: 0.7756 - val_loss: 1.8530 - val_accuracy: 0.8269 - 166ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_186"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_372 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_373 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_186 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.06981, saving model to model_3best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.73981, saving model to model_3best_val_loss.h5
# 3/3 - 3s - loss: 2.1428 - accuracy: 0.6320 - val_loss: 2.0698 - val_accuracy: 0.7398 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.06981 to 1.99532, saving model to model_3best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.73981 to 0.76481, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 2.0678 - accuracy: 0.7160 - val_loss: 1.9953 - val_accuracy: 0.7648 - 170ms/epoch - 57ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.99532 to 1.91911, saving model to model_3best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.76481 to 0.78148, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.9945 - accuracy: 0.7393 - val_loss: 1.9191 - val_accuracy: 0.7815 - 167ms/epoch - 56ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.91911 to 1.83992, saving model to model_3best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.78148 to 0.79444, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.9179 - accuracy: 0.7575 - val_loss: 1.8399 - val_accuracy: 0.7944 - 163ms/epoch - 54ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.83992 to 1.75699, saving model to model_3best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.79444 to 0.80463, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.8409 - accuracy: 0.7772 - val_loss: 1.7570 - val_accuracy: 0.8046 - 163ms/epoch - 54ms/step
# layer: 0
# Model: "sequential_187"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_374 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_375 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_187 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.25436, saving model to model_4best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.05093, saving model to model_4best_val_loss.h5
# 3/3 - 3s - loss: 2.3185 - accuracy: 0.0332 - val_loss: 2.2544 - val_accuracy: 0.0509 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.25436 to 2.14190, saving model to model_4best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.05093 to 0.66667, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 2.2011 - accuracy: 0.3487 - val_loss: 2.1419 - val_accuracy: 0.6667 - 163ms/epoch - 54ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.14190 to 2.02768, saving model to model_4best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.66667 to 0.69167, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 2.0835 - accuracy: 0.7310 - val_loss: 2.0277 - val_accuracy: 0.6917 - 165ms/epoch - 55ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.02768 to 1.91160, saving model to model_4best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.69167 to 0.70185, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 1.9669 - accuracy: 0.7666 - val_loss: 1.9116 - val_accuracy: 0.7019 - 162ms/epoch - 54ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.91160 to 1.79455, saving model to model_4best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.70185 to 0.71111, saving model to model_4best_val_loss.h5
# 3/3 - 0s - loss: 1.8454 - accuracy: 0.7816 - val_loss: 1.7946 - val_accuracy: 0.7111 - 162ms/epoch - 54ms/step
# layer: 0
# Model: "sequential_188"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_376 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_377 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_188 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.29243, saving model to model_5best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.08426, saving model to model_5best_val_loss.h5
# 3/3 - 3s - loss: 2.3333 - accuracy: 0.0330 - val_loss: 2.2924 - val_accuracy: 0.0843 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.29243 to 2.21940, saving model to model_5best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.08426 to 0.58889, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 2.2584 - accuracy: 0.3550 - val_loss: 2.2194 - val_accuracy: 0.5889 - 164ms/epoch - 55ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.21940 to 2.14744, saving model to model_5best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.58889 to 0.63426, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 2.1871 - accuracy: 0.6626 - val_loss: 2.1474 - val_accuracy: 0.6343 - 163ms/epoch - 54ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.14744 to 2.08010, saving model to model_5best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.63426 to 0.66296, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 2.1107 - accuracy: 0.7025 - val_loss: 2.0801 - val_accuracy: 0.6630 - 163ms/epoch - 54ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 2.08010 to 2.00436, saving model to model_5best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.66296 to 0.68056, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 2.0385 - accuracy: 0.7211 - val_loss: 2.0044 - val_accuracy: 0.6806 - 162ms/epoch - 54ms/step
# layer: 0
# Model: "sequential_189"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_378 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_379 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_189 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.29740, saving model to model_6best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.00741, saving model to model_6best_val_loss.h5
# 3/3 - 3s - loss: 2.3503 - accuracy: 0.0209 - val_loss: 2.2974 - val_accuracy: 0.0074 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.29740 to 2.21456, saving model to model_6best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.00741 to 0.02222, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 2.2738 - accuracy: 0.0306 - val_loss: 2.2146 - val_accuracy: 0.0222 - 164ms/epoch - 55ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.21456 to 2.13263, saving model to model_6best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.02222 to 0.16019, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 2.2013 - accuracy: 0.0870 - val_loss: 2.1326 - val_accuracy: 0.1602 - 162ms/epoch - 54ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 2.13263 to 2.04864, saving model to model_6best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.16019 to 0.27407, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 2.1258 - accuracy: 0.2392 - val_loss: 2.0486 - val_accuracy: 0.2741 - 165ms/epoch - 55ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 2.04864 to 1.95971, saving model to model_6best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.27407 to 0.87500, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 2.0510 - accuracy: 0.5766 - val_loss: 1.9597 - val_accuracy: 0.8750 - 164ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_190"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_380 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_381 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_190 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.12904, saving model to model_7best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.63241, saving model to model_7best_val_loss.h5
# 3/3 - 3s - loss: 2.1944 - accuracy: 0.2798 - val_loss: 2.1290 - val_accuracy: 0.6324 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.12904 to 2.04887, saving model to model_7best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.63241 to 0.69167, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 2.1143 - accuracy: 0.6388 - val_loss: 2.0489 - val_accuracy: 0.6917 - 163ms/epoch - 54ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 2.04887 to 1.96425, saving model to model_7best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.69167 to 0.74167, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 2.0380 - accuracy: 0.7179 - val_loss: 1.9642 - val_accuracy: 0.7417 - 166ms/epoch - 55ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.96425 to 1.88367, saving model to model_7best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.74167 to 0.75185, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 1.9561 - accuracy: 0.7530 - val_loss: 1.8837 - val_accuracy: 0.7519 - 163ms/epoch - 54ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.88367 to 1.80195, saving model to model_7best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.75185 to 0.78148, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 1.8742 - accuracy: 0.7741 - val_loss: 1.8019 - val_accuracy: 0.7815 - 164ms/epoch - 55ms/step
# layer: 0
# Model: "sequential_191"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_382 (Bidirect  (None, 120, 20)          2160
#  ional)
#
#  bidirectional_383 (Bidirect  (None, 120, 20)          2480
#  ional)
#
#  time_distributed_191 (TimeD  (None, 120, 10)          210
#  istributed)
#
# =================================================================
# Total params: 4,850
# Trainable params: 4,850
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.21969, saving model to model_8best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.03796, saving model to model_8best_val_loss.h5
# ...
#
# Epoch 2: val_accuracy improved from 0.85093 to 0.88241, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.7158 - accuracy: 0.7831 - val_loss: 1.3760 - val_accuracy: 0.8824 - 220ms/epoch - 73ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.37599 to 1.00150, saving model to model_3best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.88241 to 0.88426, saving model to model_3best_val_loss.h5
# 3/3 - 0s - loss: 1.3815 - accuracy: 0.8214 - val_loss: 1.0015 - val_accuracy: 0.8843 - 219ms/epoch - 73ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.00150 to 0.69396, saving model to model_3best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.88426
# 3/3 - 0s - loss: 1.0544 - accuracy: 0.8349 - val_loss: 0.6940 - val_accuracy: 0.8843 - 202ms/epoch - 67ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 0.69396 to 0.52327, saving model to model_3best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.88426
# 3/3 - 0s - loss: 0.8035 - accuracy: 0.8357 - val_loss: 0.5233 - val_accuracy: 0.8843 - 200ms/epoch - 67ms/step
# layer: 0
# Model: "sequential_197"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_394 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_395 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_197 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 1.93294, saving model to model_4best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.79537, saving model to model_4best_val_loss.h5
# 3/3 - 3s - loss: 2.1104 - accuracy: 0.6618 - val_loss: 1.9329 - val_accuracy: 0.7954 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 1.93294 to 1.62612, saving model to model_4best_val_accuracy.h5
#
# Epoch 2: val_accuracy did not improve from 0.79537
# 3/3 - 0s - loss: 1.8251 - accuracy: 0.8445 - val_loss: 1.6261 - val_accuracy: 0.7954 - 199ms/epoch - 66ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.62612 to 1.28808, saving model to model_4best_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.79537
# 3/3 - 0s - loss: 1.4809 - accuracy: 0.8457 - val_loss: 1.2881 - val_accuracy: 0.7954 - 200ms/epoch - 67ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.28808 to 1.00314, saving model to model_4best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.79537
# 3/3 - 0s - loss: 1.1171 - accuracy: 0.8457 - val_loss: 1.0031 - val_accuracy: 0.7954 - 196ms/epoch - 65ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.00314 to 0.84641, saving model to model_4best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.79537
# 3/3 - 0s - loss: 0.8322 - accuracy: 0.8457 - val_loss: 0.8464 - val_accuracy: 0.7954 - 199ms/epoch - 66ms/step
# layer: 0
# Model: "sequential_198"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_396 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_397 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_198 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.08040, saving model to model_5best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.59630, saving model to model_5best_val_loss.h5
# 3/3 - 4s - loss: 2.2907 - accuracy: 0.0396 - val_loss: 2.0804 - val_accuracy: 0.5963 - 4s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.08040 to 1.78802, saving model to model_5best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.59630 to 0.75278, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 2.0120 - accuracy: 0.6540 - val_loss: 1.7880 - val_accuracy: 0.7528 - 215ms/epoch - 72ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.78802 to 1.46128, saving model to model_5best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.75278 to 0.80370, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.7079 - accuracy: 0.7859 - val_loss: 1.4613 - val_accuracy: 0.8037 - 218ms/epoch - 73ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.46128 to 1.13027, saving model to model_5best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.80370 to 0.82685, saving model to model_5best_val_loss.h5
# 3/3 - 0s - loss: 1.3723 - accuracy: 0.8226 - val_loss: 1.1303 - val_accuracy: 0.8269 - 214ms/epoch - 71ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.13027 to 0.85842, saving model to model_5best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.82685
# 3/3 - 0s - loss: 1.0401 - accuracy: 0.8417 - val_loss: 0.8584 - val_accuracy: 0.8269 - 197ms/epoch - 66ms/step
# layer: 0
# Model: "sequential_199"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_398 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_399 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_199 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.00768, saving model to model_6best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.70833, saving model to model_6best_val_loss.h5
# 3/3 - 3s - loss: 2.1735 - accuracy: 0.1462 - val_loss: 2.0077 - val_accuracy: 0.7083 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.00768 to 1.70844, saving model to model_6best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.70833 to 0.79722, saving model to model_6best_val_loss.h5
# 3/3 - 0s - loss: 1.8897 - accuracy: 0.8001 - val_loss: 1.7084 - val_accuracy: 0.7972 - 216ms/epoch - 72ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.70844 to 1.40125, saving model to model_6best_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.79722
# 3/3 - 0s - loss: 1.5783 - accuracy: 0.8454 - val_loss: 1.4013 - val_accuracy: 0.7972 - 198ms/epoch - 66ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.40125 to 1.13244, saving model to model_6best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.79722
# 3/3 - 0s - loss: 1.2619 - accuracy: 0.8455 - val_loss: 1.1324 - val_accuracy: 0.7972 - 199ms/epoch - 66ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.13244 to 0.93944, saving model to model_6best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.79722
# 3/3 - 0s - loss: 0.9851 - accuracy: 0.8455 - val_loss: 0.9394 - val_accuracy: 0.7972 - 198ms/epoch - 66ms/step
# layer: 0
# Model: "sequential_200"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_400 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_401 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_200 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.04624, saving model to model_7best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.71574, saving model to model_7best_val_loss.h5
# 3/3 - 3s - loss: 2.2197 - accuracy: 0.3369 - val_loss: 2.0462 - val_accuracy: 0.7157 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.04624 to 1.77254, saving model to model_7best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.71574 to 0.84537, saving model to model_7best_val_loss.h5
# 3/3 - 0s - loss: 1.9626 - accuracy: 0.7874 - val_loss: 1.7725 - val_accuracy: 0.8454 - 216ms/epoch - 72ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.77254 to 1.47389, saving model to model_7best_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.84537
# 3/3 - 0s - loss: 1.6807 - accuracy: 0.8376 - val_loss: 1.4739 - val_accuracy: 0.8454 - 199ms/epoch - 66ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.47389 to 1.16911, saving model to model_7best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.84537
# 3/3 - 0s - loss: 1.3774 - accuracy: 0.8400 - val_loss: 1.1691 - val_accuracy: 0.8454 - 199ms/epoch - 66ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.16911 to 0.91036, saving model to model_7best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.84537
# 3/3 - 0s - loss: 1.0890 - accuracy: 0.8401 - val_loss: 0.9104 - val_accuracy: 0.8454 - 198ms/epoch - 66ms/step
# layer: 0
# Model: "sequential_201"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_402 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_403 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_201 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.01982, saving model to model_8best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.74167, saving model to model_8best_val_loss.h5
# 3/3 - 3s - loss: 2.2216 - accuracy: 0.1040 - val_loss: 2.0198 - val_accuracy: 0.7417 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.01982 to 1.75555, saving model to model_8best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.74167 to 0.81944, saving model to model_8best_val_loss.h5
# 3/3 - 0s - loss: 1.9496 - accuracy: 0.7943 - val_loss: 1.7555 - val_accuracy: 0.8194 - 218ms/epoch - 73ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.75555 to 1.48197, saving model to model_8best_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.81944
# 3/3 - 0s - loss: 1.6792 - accuracy: 0.8380 - val_loss: 1.4820 - val_accuracy: 0.8194 - 202ms/epoch - 67ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.48197 to 1.20160, saving model to model_8best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.81944
# 3/3 - 0s - loss: 1.3937 - accuracy: 0.8429 - val_loss: 1.2016 - val_accuracy: 0.8194 - 202ms/epoch - 67ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.20160 to 0.95441, saving model to model_8best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.81944
# 3/3 - 0s - loss: 1.1056 - accuracy: 0.8430 - val_loss: 0.9544 - val_accuracy: 0.8194 - 201ms/epoch - 67ms/step
# layer: 0
# Model: "sequential_202"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_404 (Bidirect  (None, 120, 60)          11280
#  ional)
#
#  bidirectional_405 (Bidirect  (None, 120, 60)          21840
#  ional)
#
#  time_distributed_202 (TimeD  (None, 120, 10)          610
#  istributed)
#
# =================================================================
# Total params: 33,730
# Trainable params: 33,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
#
# Epoch 1: val_loss improved from inf to 2.04277, saving model to model_9best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.79444, saving model to model_9best_val_loss.h5
# 3/3 - 3s - loss: 2.2472 - accuracy: 0.1607 - val_loss: 2.0428 - val_accuracy: 0.7944 - 3s/epoch - 1s/step
# Epoch 2/5
#
# Epoch 2: val_loss improved from 2.04277 to 1.75781, saving model to model_9best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.79444 to 0.85370, saving model to model_9best_val_loss.h5
# 3/3 - 0s - loss: 1.9830 - accuracy: 0.8082 - val_loss: 1.7578 - val_accuracy: 0.8537 - 218ms/epoch - 73ms/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 1.75781 to 1.44890, saving model to model_9best_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.85370
# 3/3 - 0s - loss: 1.6963 - accuracy: 0.8392 - val_loss: 1.4489 - val_accuracy: 0.8537 - 204ms/epoch - 68ms/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 1.44890 to 1.13026, saving model to model_9best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.85370
# 3/3 - 0s - loss: 1.3899 - accuracy: 0.8393 - val_loss: 1.1303 - val_accuracy: 0.8537 - 199ms/epoch - 66ms/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 1.13026 to 0.85471, saving model to model_9best_val_accuracy.h5
#
# Epoch 5: val_accuracy did not improve from 0.85370
# 3/3 - 0s - loss: 1.0924 - accuracy: 0.8392 - val_loss: 0.8547 - val_accuracy: 0.8537 - 197ms/epoch - 66ms/step
# Best params: {'neurons': 30, 'dropout': 0.2}
# Best validation loss: 0.8318

# %%
n_splits = 2
history_out = 'output/history'
model = train_model.Model('phrog_annotation_info/phrog_integer.pkl', features_include = 'all')
model.fit_data('test_data/test_training_data.pkl')
model.train_crossValidation(epochs=5, n_splits=n_splits, history_out=history_out)
# Out:
# HISTORY OUT: output/history_0
# layer: 0
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_52 (Bidirecti  (None, 120, 4)           304
#  onal)
#
#  bidirectional_53 (Bidirecti  (None, 120, 4)           112
#  onal)
#
#  time_distributed_26 (TimeDi  (None, 120, 10)          50
#  stributed)
#
# =================================================================
# Total params: 466
# Trainable params: 466
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 1/2 [==============>...............] - ETA: 3s - loss: 2.2939 - accuracy: 0.0221
# Epoch 1: val_loss improved from inf to 2.28844, saving model to model_0best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.03278, saving model to model_0best_val_loss.h5
# 2/2 [==============================] - 4s 693ms/step - loss: 2.2932 - accuracy: 0.0254 - val_loss: 2.2884 - val_accuracy: 0.0328
# Epoch 2/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2859 - accuracy: 0.0305
# Epoch 2: val_loss improved from 2.28844 to 2.28144, saving model to model_0best_val_accuracy.h5
#
# Epoch 2: val_accuracy did not improve from 0.03278
# 2/2 [==============================] - 0s 80ms/step - loss: 2.2855 - accuracy: 0.0289 - val_loss: 2.2814 - val_accuracy: 0.0328
# Epoch 3/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2790 - accuracy: 0.0294
# Epoch 3: val_loss improved from 2.28144 to 2.27445, saving model to model_0best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.03278 to 0.03296, saving model to model_0best_val_loss.h5
# 2/2 [==============================] - 0s 98ms/step - loss: 2.2779 - accuracy: 0.0307 - val_loss: 2.2745 - val_accuracy: 0.0330
# Epoch 4/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2726 - accuracy: 0.0339
# Epoch 4: val_loss improved from 2.27445 to 2.26746, saving model to model_0best_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.03296
# 2/2 [==============================] - 0s 82ms/step - loss: 2.2717 - accuracy: 0.0326 - val_loss: 2.2675 - val_accuracy: 0.0319
# Epoch 5/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.2665 - accuracy: 0.0706
# Epoch 5: val_loss improved from 2.26746 to 2.26051, saving model to model_0best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.03296 to 0.06148, saving model to model_0best_val_loss.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 2.2646 - accuracy: 0.0944 - val_loss: 2.2605 - val_accuracy: 0.0615
# WARNING:absl:Found untraced functions such as lstm_cell_157_layer_call_fn, lstm_cell_157_layer_call_and_return_conditional_losses, lstm_cell_158_layer_call_fn, lstm_cell_158_layer_call_and_return_conditional_losses, lstm_cell_160_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_0.pkl/assets
# INFO:tensorflow:Assets written to: model_0.pkl/assets
# HISTORY SAVED TO: output/history_0.pkl
# HISTORY OUT: output/history_1
# layer: 0
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_54 (Bidirecti  (None, 120, 4)           304
#  onal)
#
#  bidirectional_55 (Bidirecti  (None, 120, 4)           112
#  onal)
#
#  time_distributed_27 (TimeDi  (None, 120, 10)          50
#  stributed)
#
# =================================================================
# Total params: 466
# Trainable params: 466
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 1/2 [==============>...............] - ETA: 2s - loss: 2.1859 - accuracy: 0.0521
# Epoch 1: val_loss improved from inf to 2.17480, saving model to model_1best_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.09796, saving model to model_1best_val_loss.h5
# 2/2 [==============================] - 3s 670ms/step - loss: 2.1804 - accuracy: 0.0541 - val_loss: 2.1748 - val_accuracy: 0.0980
# Epoch 2/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1714 - accuracy: 0.0719
# Epoch 2: val_loss improved from 2.17480 to 2.16213, saving model to model_1best_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.09796 to 0.11833, saving model to model_1best_val_loss.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 2.1701 - accuracy: 0.0765 - val_loss: 2.1621 - val_accuracy: 0.1183
# Epoch 3/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1637 - accuracy: 0.0831
# Epoch 3: val_loss improved from 2.16213 to 2.14951, saving model to model_1best_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.11833 to 0.14148, saving model to model_1best_val_loss.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 2.1583 - accuracy: 0.0857 - val_loss: 2.1495 - val_accuracy: 0.1415
# Epoch 4/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1414 - accuracy: 0.1135
# Epoch 4: val_loss improved from 2.14951 to 2.13685, saving model to model_1best_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.14148 to 0.17056, saving model to model_1best_val_loss.h5
# 2/2 [==============================] - 0s 97ms/step - loss: 2.1441 - accuracy: 0.1241 - val_loss: 2.1369 - val_accuracy: 0.1706
# Epoch 5/5
# 1/2 [==============>...............] - ETA: 0s - loss: 2.1324 - accuracy: 0.2104
# Epoch 5: val_loss improved from 2.13685 to 2.12414, saving model to model_1best_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.17056 to 0.27185, saving model to model_1best_val_loss.h5
# 2/2 [==============================] - 0s 100ms/step - loss: 2.1290 - accuracy: 0.2148 - val_loss: 2.1241 - val_accuracy: 0.2719
# WARNING:absl:Found untraced functions such as lstm_cell_163_layer_call_fn, lstm_cell_163_layer_call_and_return_conditional_losses, lstm_cell_164_layer_call_fn, lstm_cell_164_layer_call_and_return_conditional_losses, lstm_cell_166_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model_1.pkl/assets
# INFO:tensorflow:Assets written to: model_1.pkl/assets
# HISTORY SAVED TO: output/history_1.pkl

# %%
# write a little function using glob to get the mean loss from the output history dictionaries
import glob
# Out:
# /Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=10.
#   warnings.warn(
# layer: 0
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_46 (Bidirecti  (None, 120, 4)           304
#  onal)
#
#  bidirectional_47 (Bidirecti  (None, 120, 4)           112
#  onal)
#
#  time_distributed_27 (TimeDi  (None, 120, 10)          50
#  stributed)
#
# =================================================================
# Total params: 466
# Trainable params: 466
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/140
# 3/3 [==============================] - ETA: 0s - loss: 2.4366 - accuracy: 0.0146
# Epoch 1: val_loss improved from inf to 2.39559, saving model to modelbest_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.01944, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 4s 384ms/step - loss: 2.4366 - accuracy: 0.0146 - val_loss: 2.3956 - val_accuracy: 0.0194
# Epoch 2/140
# 3/3 [==============================] - ETA: 0s - loss: 2.4175 - accuracy: 0.0154
# Epoch 2: val_loss improved from 2.39559 to 2.37878, saving model to modelbest_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.01944 to 0.02037, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.4175 - accuracy: 0.0154 - val_loss: 2.3788 - val_accuracy: 0.0204
# Epoch 3/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3963 - accuracy: 0.0149
# Epoch 3: val_loss improved from 2.37878 to 2.36237, saving model to modelbest_val_accuracy.h5
#
# Epoch 3: val_accuracy did not improve from 0.02037
# 3/3 [==============================] - 0s 54ms/step - loss: 2.3963 - accuracy: 0.0149 - val_loss: 2.3624 - val_accuracy: 0.0204
# Epoch 4/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3796 - accuracy: 0.0157
# Epoch 4: val_loss improved from 2.36237 to 2.34679, saving model to modelbest_val_accuracy.h5
#
# Epoch 4: val_accuracy did not improve from 0.02037
# 3/3 [==============================] - 0s 54ms/step - loss: 2.3796 - accuracy: 0.0157 - val_loss: 2.3468 - val_accuracy: 0.0204
# Epoch 5/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3626 - accuracy: 0.0159
# Epoch 5: val_loss improved from 2.34679 to 2.33189, saving model to modelbest_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.02037 to 0.02130, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 2.3626 - accuracy: 0.0159 - val_loss: 2.3319 - val_accuracy: 0.0213
# Epoch 6/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3457 - accuracy: 0.0159
# Epoch 6: val_loss improved from 2.33189 to 2.31783, saving model to modelbest_val_accuracy.h5
#
# Epoch 6: val_accuracy improved from 0.02130 to 0.02315, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 61ms/step - loss: 2.3457 - accuracy: 0.0159 - val_loss: 2.3178 - val_accuracy: 0.0231
# Epoch 7/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3287 - accuracy: 0.0176
# Epoch 7: val_loss improved from 2.31783 to 2.30463, saving model to modelbest_val_accuracy.h5
#
# Epoch 7: val_accuracy improved from 0.02315 to 0.02407, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.3287 - accuracy: 0.0176 - val_loss: 2.3046 - val_accuracy: 0.0241
# Epoch 8/140
# 3/3 [==============================] - ETA: 0s - loss: 2.3140 - accuracy: 0.0204
# Epoch 8: val_loss improved from 2.30463 to 2.29213, saving model to modelbest_val_accuracy.h5
#
# Epoch 8: val_accuracy improved from 0.02407 to 0.02870, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.3140 - accuracy: 0.0204 - val_loss: 2.2921 - val_accuracy: 0.0287
# Epoch 9/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2997 - accuracy: 0.0237
# Epoch 9: val_loss improved from 2.29213 to 2.28029, saving model to modelbest_val_accuracy.h5
#
# Epoch 9: val_accuracy improved from 0.02870 to 0.03333, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 2.2997 - accuracy: 0.0237 - val_loss: 2.2803 - val_accuracy: 0.0333
# Epoch 10/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2862 - accuracy: 0.0354
# Epoch 10: val_loss improved from 2.28029 to 2.26902, saving model to modelbest_val_accuracy.h5
#
# Epoch 10: val_accuracy improved from 0.03333 to 0.03889, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.2862 - accuracy: 0.0354 - val_loss: 2.2690 - val_accuracy: 0.0389
# Epoch 11/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2741 - accuracy: 0.0462
# Epoch 11: val_loss improved from 2.26902 to 2.25828, saving model to modelbest_val_accuracy.h5
#
# Epoch 11: val_accuracy improved from 0.03889 to 0.04907, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.2741 - accuracy: 0.0462 - val_loss: 2.2583 - val_accuracy: 0.0491
# Epoch 12/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2622 - accuracy: 0.0574
# Epoch 12: val_loss improved from 2.25828 to 2.24802, saving model to modelbest_val_accuracy.h5
#
# Epoch 12: val_accuracy improved from 0.04907 to 0.06944, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.2622 - accuracy: 0.0574 - val_loss: 2.2480 - val_accuracy: 0.0694
# Epoch 13/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2503 - accuracy: 0.0823
# Epoch 13: val_loss improved from 2.24802 to 2.23816, saving model to modelbest_val_accuracy.h5
#
# Epoch 13: val_accuracy improved from 0.06944 to 0.13426, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.2503 - accuracy: 0.0823 - val_loss: 2.2382 - val_accuracy: 0.1343
# Epoch 14/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2391 - accuracy: 0.1274
# Epoch 14: val_loss improved from 2.23816 to 2.22857, saving model to modelbest_val_accuracy.h5
#
# Epoch 14: val_accuracy improved from 0.13426 to 0.20185, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.2391 - accuracy: 0.1274 - val_loss: 2.2286 - val_accuracy: 0.2019
# Epoch 15/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2288 - accuracy: 0.1924
# Epoch 15: val_loss improved from 2.22857 to 2.21924, saving model to modelbest_val_accuracy.h5
#
# Epoch 15: val_accuracy improved from 0.20185 to 0.28148, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 62ms/step - loss: 2.2288 - accuracy: 0.1924 - val_loss: 2.2192 - val_accuracy: 0.2815
# Epoch 16/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2191 - accuracy: 0.3315
# Epoch 16: val_loss improved from 2.21924 to 2.21013, saving model to modelbest_val_accuracy.h5
#
# Epoch 16: val_accuracy improved from 0.28148 to 0.74259, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.2191 - accuracy: 0.3315 - val_loss: 2.2101 - val_accuracy: 0.7426
# Epoch 17/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2081 - accuracy: 0.6181
# Epoch 17: val_loss improved from 2.21013 to 2.20120, saving model to modelbest_val_accuracy.h5
#
# Epoch 17: val_accuracy improved from 0.74259 to 0.75556, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 2.2081 - accuracy: 0.6181 - val_loss: 2.2012 - val_accuracy: 0.7556
# Epoch 18/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1985 - accuracy: 0.7967
# Epoch 18: val_loss improved from 2.20120 to 2.19236, saving model to modelbest_val_accuracy.h5
#
# Epoch 18: val_accuracy improved from 0.75556 to 0.76574, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 2.1985 - accuracy: 0.7967 - val_loss: 2.1924 - val_accuracy: 0.7657
# Epoch 19/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1882 - accuracy: 0.8238
# Epoch 19: val_loss improved from 2.19236 to 2.18358, saving model to modelbest_val_accuracy.h5
#
# Epoch 19: val_accuracy improved from 0.76574 to 0.77315, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.1882 - accuracy: 0.8238 - val_loss: 2.1836 - val_accuracy: 0.7731
# Epoch 20/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1785 - accuracy: 0.8300
# Epoch 20: val_loss improved from 2.18358 to 2.17476, saving model to modelbest_val_accuracy.h5
#
# Epoch 20: val_accuracy improved from 0.77315 to 0.78056, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.1785 - accuracy: 0.8300 - val_loss: 2.1748 - val_accuracy: 0.7806
# Epoch 21/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1684 - accuracy: 0.8370
# Epoch 21: val_loss improved from 2.17476 to 2.16593, saving model to modelbest_val_accuracy.h5
#
# Epoch 21: val_accuracy improved from 0.78056 to 0.79167, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.1684 - accuracy: 0.8370 - val_loss: 2.1659 - val_accuracy: 0.7917
# Epoch 22/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1589 - accuracy: 0.8384
# Epoch 22: val_loss improved from 2.16593 to 2.15704, saving model to modelbest_val_accuracy.h5
#
# Epoch 22: val_accuracy improved from 0.79167 to 0.79722, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.1589 - accuracy: 0.8384 - val_loss: 2.1570 - val_accuracy: 0.7972
# Epoch 23/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1488 - accuracy: 0.8418
# Epoch 23: val_loss improved from 2.15704 to 2.14807, saving model to modelbest_val_accuracy.h5
#
# Epoch 23: val_accuracy improved from 0.79722 to 0.80278, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.1488 - accuracy: 0.8418 - val_loss: 2.1481 - val_accuracy: 0.8028
# Epoch 24/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1395 - accuracy: 0.8404
# Epoch 24: val_loss improved from 2.14807 to 2.13894, saving model to modelbest_val_accuracy.h5
#
# Epoch 24: val_accuracy improved from 0.80278 to 0.80370, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.1395 - accuracy: 0.8404 - val_loss: 2.1389 - val_accuracy: 0.8037
# Epoch 25/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1289 - accuracy: 0.8424
# Epoch 25: val_loss improved from 2.13894 to 2.12968, saving model to modelbest_val_accuracy.h5
#
# Epoch 25: val_accuracy improved from 0.80370 to 0.80556, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.1289 - accuracy: 0.8424 - val_loss: 2.1297 - val_accuracy: 0.8056
# Epoch 26/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1187 - accuracy: 0.8419
# Epoch 26: val_loss improved from 2.12968 to 2.12018, saving model to modelbest_val_accuracy.h5
#
# Epoch 26: val_accuracy improved from 0.80556 to 0.80648, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.1187 - accuracy: 0.8419 - val_loss: 2.1202 - val_accuracy: 0.8065
# Epoch 27/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1082 - accuracy: 0.8433
# Epoch 27: val_loss improved from 2.12018 to 2.11048, saving model to modelbest_val_accuracy.h5
#
# Epoch 27: val_accuracy did not improve from 0.80648
# 3/3 [==============================] - 0s 55ms/step - loss: 2.1082 - accuracy: 0.8433 - val_loss: 2.1105 - val_accuracy: 0.8065
# Epoch 28/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0971 - accuracy: 0.8432
# Epoch 28: val_loss improved from 2.11048 to 2.10057, saving model to modelbest_val_accuracy.h5
#
# Epoch 28: val_accuracy improved from 0.80648 to 0.80741, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 63ms/step - loss: 2.0971 - accuracy: 0.8432 - val_loss: 2.1006 - val_accuracy: 0.8074
# Epoch 29/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0867 - accuracy: 0.8437
# Epoch 29: val_loss improved from 2.10057 to 2.09036, saving model to modelbest_val_accuracy.h5
#
# Epoch 29: val_accuracy did not improve from 0.80741
# 3/3 [==============================] - 0s 55ms/step - loss: 2.0867 - accuracy: 0.8437 - val_loss: 2.0904 - val_accuracy: 0.8074
# Epoch 30/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0757 - accuracy: 0.8439
# Epoch 30: val_loss improved from 2.09036 to 2.07982, saving model to modelbest_val_accuracy.h5
#
# Epoch 30: val_accuracy did not improve from 0.80741
# 3/3 [==============================] - 0s 55ms/step - loss: 2.0757 - accuracy: 0.8439 - val_loss: 2.0798 - val_accuracy: 0.8074
# Epoch 31/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0634 - accuracy: 0.8441
# Epoch 31: val_loss improved from 2.07982 to 2.06896, saving model to modelbest_val_accuracy.h5
#
# Epoch 31: val_accuracy improved from 0.80741 to 0.80833, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.0634 - accuracy: 0.8441 - val_loss: 2.0690 - val_accuracy: 0.8083
# Epoch 32/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0514 - accuracy: 0.8440
# Epoch 32: val_loss improved from 2.06896 to 2.05782, saving model to modelbest_val_accuracy.h5
#
# Epoch 32: val_accuracy did not improve from 0.80833
# 3/3 [==============================] - 0s 55ms/step - loss: 2.0514 - accuracy: 0.8440 - val_loss: 2.0578 - val_accuracy: 0.8083
# Epoch 33/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0399 - accuracy: 0.8441
# Epoch 33: val_loss improved from 2.05782 to 2.04636, saving model to modelbest_val_accuracy.h5
#
# Epoch 33: val_accuracy did not improve from 0.80833
# 3/3 [==============================] - 0s 53ms/step - loss: 2.0399 - accuracy: 0.8441 - val_loss: 2.0464 - val_accuracy: 0.8083
# Epoch 34/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0266 - accuracy: 0.8441
# Epoch 34: val_loss improved from 2.04636 to 2.03454, saving model to modelbest_val_accuracy.h5
#
# Epoch 34: val_accuracy did not improve from 0.80833
# 3/3 [==============================] - 0s 55ms/step - loss: 2.0266 - accuracy: 0.8441 - val_loss: 2.0345 - val_accuracy: 0.8083
# Epoch 35/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0138 - accuracy: 0.8441
# Epoch 35: val_loss improved from 2.03454 to 2.02217, saving model to modelbest_val_accuracy.h5
#
# Epoch 35: val_accuracy did not improve from 0.80833
# 3/3 [==============================] - 0s 54ms/step - loss: 2.0138 - accuracy: 0.8441 - val_loss: 2.0222 - val_accuracy: 0.8083
# Epoch 36/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0003 - accuracy: 0.8441
# Epoch 36: val_loss improved from 2.02217 to 2.00929, saving model to modelbest_val_accuracy.h5
#
# Epoch 36: val_accuracy improved from 0.80833 to 0.80926, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.0003 - accuracy: 0.8441 - val_loss: 2.0093 - val_accuracy: 0.8093
# Epoch 37/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9860 - accuracy: 0.8441
# Epoch 37: val_loss improved from 2.00929 to 1.99613, saving model to modelbest_val_accuracy.h5
#
# Epoch 37: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.9860 - accuracy: 0.8441 - val_loss: 1.9961 - val_accuracy: 0.8093
# Epoch 38/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9713 - accuracy: 0.8441
# Epoch 38: val_loss improved from 1.99613 to 1.98261, saving model to modelbest_val_accuracy.h5
#
# Epoch 38: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.9713 - accuracy: 0.8441 - val_loss: 1.9826 - val_accuracy: 0.8093
# Epoch 39/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9572 - accuracy: 0.8441
# Epoch 39: val_loss improved from 1.98261 to 1.96867, saving model to modelbest_val_accuracy.h5
#
# Epoch 39: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.9572 - accuracy: 0.8441 - val_loss: 1.9687 - val_accuracy: 0.8093
# Epoch 40/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9408 - accuracy: 0.8441
# Epoch 40: val_loss improved from 1.96867 to 1.95427, saving model to modelbest_val_accuracy.h5
#
# Epoch 40: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.9408 - accuracy: 0.8441 - val_loss: 1.9543 - val_accuracy: 0.8093
# Epoch 41/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9252 - accuracy: 0.8441
# Epoch 41: val_loss improved from 1.95427 to 1.93942, saving model to modelbest_val_accuracy.h5
#
# Epoch 41: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.9252 - accuracy: 0.8441 - val_loss: 1.9394 - val_accuracy: 0.8093
# Epoch 42/140
# 3/3 [==============================] - ETA: 0s - loss: 1.9087 - accuracy: 0.8441
# Epoch 42: val_loss improved from 1.93942 to 1.92411, saving model to modelbest_val_accuracy.h5
#
# Epoch 42: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.9087 - accuracy: 0.8441 - val_loss: 1.9241 - val_accuracy: 0.8093
# Epoch 43/140
# 3/3 [==============================] - ETA: 0s - loss: 1.8915 - accuracy: 0.8441
# Epoch 43: val_loss improved from 1.92411 to 1.90836, saving model to modelbest_val_accuracy.h5
#
# Epoch 43: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.8915 - accuracy: 0.8441 - val_loss: 1.9084 - val_accuracy: 0.8093
# Epoch 44/140
# 3/3 [==============================] - ETA: 0s - loss: 1.8739 - accuracy: 0.8441
# Epoch 44: val_loss improved from 1.90836 to 1.89216, saving model to modelbest_val_accuracy.h5
#
# Epoch 44: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.8739 - accuracy: 0.8441 - val_loss: 1.8922 - val_accuracy: 0.8093
# Epoch 45/140
# 3/3 [==============================] - ETA: 0s - loss: 1.8564 - accuracy: 0.8441
# Epoch 45: val_loss improved from 1.89216 to 1.87547, saving model to modelbest_val_accuracy.h5
#
# Epoch 45: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 1.8564 - accuracy: 0.8441 - val_loss: 1.8755 - val_accuracy: 0.8093
# Epoch 46/140
# 3/3 [==============================] - ETA: 0s - loss: 1.8377 - accuracy: 0.8441
# Epoch 46: val_loss improved from 1.87547 to 1.85835, saving model to modelbest_val_accuracy.h5
#
# Epoch 46: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.8377 - accuracy: 0.8441 - val_loss: 1.8584 - val_accuracy: 0.8093
# Epoch 47/140
# 3/3 [==============================] - ETA: 0s - loss: 1.8186 - accuracy: 0.8441
# Epoch 47: val_loss improved from 1.85835 to 1.84078, saving model to modelbest_val_accuracy.h5
#
# Epoch 47: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.8186 - accuracy: 0.8441 - val_loss: 1.8408 - val_accuracy: 0.8093
# Epoch 48/140
# 3/3 [==============================] - ETA: 0s - loss: 1.7998 - accuracy: 0.8441
# Epoch 48: val_loss improved from 1.84078 to 1.82164, saving model to modelbest_val_accuracy.h5
#
# Epoch 48: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7998 - accuracy: 0.8441 - val_loss: 1.8216 - val_accuracy: 0.8093
# Epoch 49/140
# 3/3 [==============================] - ETA: 0s - loss: 1.7794 - accuracy: 0.8441
# Epoch 49: val_loss improved from 1.82164 to 1.80280, saving model to modelbest_val_accuracy.h5
#
# Epoch 49: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7794 - accuracy: 0.8441 - val_loss: 1.8028 - val_accuracy: 0.8093
# Epoch 50/140
# 3/3 [==============================] - ETA: 0s - loss: 1.7599 - accuracy: 0.8441
# Epoch 50: val_loss improved from 1.80280 to 1.78392, saving model to modelbest_val_accuracy.h5
#
# Epoch 50: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7599 - accuracy: 0.8441 - val_loss: 1.7839 - val_accuracy: 0.8093
# Epoch 51/140
# 3/3 [==============================] - ETA: 0s - loss: 1.7396 - accuracy: 0.8441
# Epoch 51: val_loss improved from 1.78392 to 1.76475, saving model to modelbest_val_accuracy.h5
#
# Epoch 51: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.7396 - accuracy: 0.8441 - val_loss: 1.7647 - val_accuracy: 0.8093
# Epoch 52/140
# 3/3 [==============================] - ETA: 0s - loss: 1.7186 - accuracy: 0.8441
# Epoch 52: val_loss improved from 1.76475 to 1.74525, saving model to modelbest_val_accuracy.h5
#
# Epoch 52: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.7186 - accuracy: 0.8441 - val_loss: 1.7453 - val_accuracy: 0.8093
# Epoch 53/140
# 3/3 [==============================] - ETA: 0s - loss: 1.6978 - accuracy: 0.8441
# Epoch 53: val_loss improved from 1.74525 to 1.72543, saving model to modelbest_val_accuracy.h5
#
# Epoch 53: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6978 - accuracy: 0.8441 - val_loss: 1.7254 - val_accuracy: 0.8093
# Epoch 54/140
# 3/3 [==============================] - ETA: 0s - loss: 1.6764 - accuracy: 0.8441
# Epoch 54: val_loss improved from 1.72543 to 1.70558, saving model to modelbest_val_accuracy.h5
#
# Epoch 54: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6764 - accuracy: 0.8441 - val_loss: 1.7056 - val_accuracy: 0.8093
# Epoch 55/140
# 3/3 [==============================] - ETA: 0s - loss: 1.6552 - accuracy: 0.8441
# Epoch 55: val_loss improved from 1.70558 to 1.68536, saving model to modelbest_val_accuracy.h5
#
# Epoch 55: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.6552 - accuracy: 0.8441 - val_loss: 1.6854 - val_accuracy: 0.8093
# Epoch 56/140
# 3/3 [==============================] - ETA: 0s - loss: 1.6324 - accuracy: 0.8441
# Epoch 56: val_loss improved from 1.68536 to 1.66284, saving model to modelbest_val_accuracy.h5
#
# Epoch 56: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.6324 - accuracy: 0.8441 - val_loss: 1.6628 - val_accuracy: 0.8093
# Epoch 57/140
# 3/3 [==============================] - ETA: 0s - loss: 1.6115 - accuracy: 0.8441
# Epoch 57: val_loss improved from 1.66284 to 1.64182, saving model to modelbest_val_accuracy.h5
#
# Epoch 57: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.6115 - accuracy: 0.8441 - val_loss: 1.6418 - val_accuracy: 0.8093
# Epoch 58/140
# 3/3 [==============================] - ETA: 0s - loss: 1.5894 - accuracy: 0.8441
# Epoch 58: val_loss improved from 1.64182 to 1.62042, saving model to modelbest_val_accuracy.h5
#
# Epoch 58: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.5894 - accuracy: 0.8441 - val_loss: 1.6204 - val_accuracy: 0.8093
# Epoch 59/140
# 3/3 [==============================] - ETA: 0s - loss: 1.5683 - accuracy: 0.8441
# Epoch 59: val_loss improved from 1.62042 to 1.59946, saving model to modelbest_val_accuracy.h5
#
# Epoch 59: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.5683 - accuracy: 0.8441 - val_loss: 1.5995 - val_accuracy: 0.8093
# Epoch 60/140
# 3/3 [==============================] - ETA: 0s - loss: 1.5467 - accuracy: 0.8441
# Epoch 60: val_loss improved from 1.59946 to 1.57868, saving model to modelbest_val_accuracy.h5
#
# Epoch 60: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.5467 - accuracy: 0.8441 - val_loss: 1.5787 - val_accuracy: 0.8093
# Epoch 61/140
# 3/3 [==============================] - ETA: 0s - loss: 1.5241 - accuracy: 0.8441
# Epoch 61: val_loss improved from 1.57868 to 1.55787, saving model to modelbest_val_accuracy.h5
#
# Epoch 61: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.5241 - accuracy: 0.8441 - val_loss: 1.5579 - val_accuracy: 0.8093
# Epoch 62/140
# 3/3 [==============================] - ETA: 0s - loss: 1.5022 - accuracy: 0.8441
# Epoch 62: val_loss improved from 1.55787 to 1.53716, saving model to modelbest_val_accuracy.h5
#
# Epoch 62: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.5022 - accuracy: 0.8441 - val_loss: 1.5372 - val_accuracy: 0.8093
# Epoch 63/140
# 3/3 [==============================] - ETA: 0s - loss: 1.4794 - accuracy: 0.8441
# Epoch 63: val_loss improved from 1.53716 to 1.51662, saving model to modelbest_val_accuracy.h5
#
# Epoch 63: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.4794 - accuracy: 0.8441 - val_loss: 1.5166 - val_accuracy: 0.8093
# Epoch 64/140
# 3/3 [==============================] - ETA: 0s - loss: 1.4574 - accuracy: 0.8441
# Epoch 64: val_loss improved from 1.51662 to 1.49615, saving model to modelbest_val_accuracy.h5
#
# Epoch 64: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.4574 - accuracy: 0.8441 - val_loss: 1.4961 - val_accuracy: 0.8093
# Epoch 65/140
# 3/3 [==============================] - ETA: 0s - loss: 1.4362 - accuracy: 0.8441
# Epoch 65: val_loss improved from 1.49615 to 1.47580, saving model to modelbest_val_accuracy.h5
#
# Epoch 65: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 1.4362 - accuracy: 0.8441 - val_loss: 1.4758 - val_accuracy: 0.8093
# Epoch 66/140
# 3/3 [==============================] - ETA: 0s - loss: 1.4138 - accuracy: 0.8441
# Epoch 66: val_loss improved from 1.47580 to 1.45560, saving model to modelbest_val_accuracy.h5
#
# Epoch 66: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 57ms/step - loss: 1.4138 - accuracy: 0.8441 - val_loss: 1.4556 - val_accuracy: 0.8093
# Epoch 67/140
# 3/3 [==============================] - ETA: 0s - loss: 1.3933 - accuracy: 0.8441
# Epoch 67: val_loss improved from 1.45560 to 1.43598, saving model to modelbest_val_accuracy.h5
#
# Epoch 67: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.3933 - accuracy: 0.8441 - val_loss: 1.4360 - val_accuracy: 0.8093
# Epoch 68/140
# 3/3 [==============================] - ETA: 0s - loss: 1.3719 - accuracy: 0.8441
# Epoch 68: val_loss improved from 1.43598 to 1.41560, saving model to modelbest_val_accuracy.h5
#
# Epoch 68: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.3719 - accuracy: 0.8441 - val_loss: 1.4156 - val_accuracy: 0.8093
# Epoch 69/140
# 3/3 [==============================] - ETA: 0s - loss: 1.3519 - accuracy: 0.8441
# Epoch 69: val_loss improved from 1.41560 to 1.39647, saving model to modelbest_val_accuracy.h5
#
# Epoch 69: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.3519 - accuracy: 0.8441 - val_loss: 1.3965 - val_accuracy: 0.8093
# Epoch 70/140
# 3/3 [==============================] - ETA: 0s - loss: 1.3313 - accuracy: 0.8441
# Epoch 70: val_loss improved from 1.39647 to 1.37779, saving model to modelbest_val_accuracy.h5
#
# Epoch 70: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.3313 - accuracy: 0.8441 - val_loss: 1.3778 - val_accuracy: 0.8093
# Epoch 71/140
# 3/3 [==============================] - ETA: 0s - loss: 1.3111 - accuracy: 0.8441
# Epoch 71: val_loss improved from 1.37779 to 1.35938, saving model to modelbest_val_accuracy.h5
#
# Epoch 71: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.3111 - accuracy: 0.8441 - val_loss: 1.3594 - val_accuracy: 0.8093
# Epoch 72/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2915 - accuracy: 0.8441
# Epoch 72: val_loss improved from 1.35938 to 1.34155, saving model to modelbest_val_accuracy.h5
#
# Epoch 72: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2915 - accuracy: 0.8441 - val_loss: 1.3415 - val_accuracy: 0.8093
# Epoch 73/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2731 - accuracy: 0.8441
# Epoch 73: val_loss improved from 1.34155 to 1.32414, saving model to modelbest_val_accuracy.h5
#
# Epoch 73: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2731 - accuracy: 0.8441 - val_loss: 1.3241 - val_accuracy: 0.8093
# Epoch 74/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2537 - accuracy: 0.8441
# Epoch 74: val_loss improved from 1.32414 to 1.30710, saving model to modelbest_val_accuracy.h5
#
# Epoch 74: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2537 - accuracy: 0.8441 - val_loss: 1.3071 - val_accuracy: 0.8093
# Epoch 75/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2356 - accuracy: 0.8441
# Epoch 75: val_loss improved from 1.30710 to 1.29059, saving model to modelbest_val_accuracy.h5
#
# Epoch 75: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2356 - accuracy: 0.8441 - val_loss: 1.2906 - val_accuracy: 0.8093
# Epoch 76/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2182 - accuracy: 0.8441
# Epoch 76: val_loss improved from 1.29059 to 1.27459, saving model to modelbest_val_accuracy.h5
#
# Epoch 76: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2182 - accuracy: 0.8441 - val_loss: 1.2746 - val_accuracy: 0.8093
# Epoch 77/140
# 3/3 [==============================] - ETA: 0s - loss: 1.2009 - accuracy: 0.8441
# Epoch 77: val_loss improved from 1.27459 to 1.25909, saving model to modelbest_val_accuracy.h5
#
# Epoch 77: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2009 - accuracy: 0.8441 - val_loss: 1.2591 - val_accuracy: 0.8093
# Epoch 78/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1843 - accuracy: 0.8441
# Epoch 78: val_loss improved from 1.25909 to 1.24399, saving model to modelbest_val_accuracy.h5
#
# Epoch 78: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.1843 - accuracy: 0.8441 - val_loss: 1.2440 - val_accuracy: 0.8093
# Epoch 79/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1690 - accuracy: 0.8441
# Epoch 79: val_loss improved from 1.24399 to 1.22932, saving model to modelbest_val_accuracy.h5
#
# Epoch 79: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1690 - accuracy: 0.8441 - val_loss: 1.2293 - val_accuracy: 0.8093
# Epoch 80/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1532 - accuracy: 0.8441
# Epoch 80: val_loss improved from 1.22932 to 1.21509, saving model to modelbest_val_accuracy.h5
#
# Epoch 80: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.1532 - accuracy: 0.8441 - val_loss: 1.2151 - val_accuracy: 0.8093
# Epoch 81/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1373 - accuracy: 0.8441
# Epoch 81: val_loss improved from 1.21509 to 1.20133, saving model to modelbest_val_accuracy.h5
#
# Epoch 81: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 1.1373 - accuracy: 0.8441 - val_loss: 1.2013 - val_accuracy: 0.8093
# Epoch 82/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1237 - accuracy: 0.8441
# Epoch 82: val_loss improved from 1.20133 to 1.18806, saving model to modelbest_val_accuracy.h5
#
# Epoch 82: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1237 - accuracy: 0.8441 - val_loss: 1.1881 - val_accuracy: 0.8093
# Epoch 83/140
# 3/3 [==============================] - ETA: 0s - loss: 1.1092 - accuracy: 0.8441
# Epoch 83: val_loss improved from 1.18806 to 1.17520, saving model to modelbest_val_accuracy.h5
#
# Epoch 83: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1092 - accuracy: 0.8441 - val_loss: 1.1752 - val_accuracy: 0.8093
# Epoch 84/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0957 - accuracy: 0.8441
# Epoch 84: val_loss improved from 1.17520 to 1.16278, saving model to modelbest_val_accuracy.h5
#
# Epoch 84: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.0957 - accuracy: 0.8441 - val_loss: 1.1628 - val_accuracy: 0.8093
# Epoch 85/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0808 - accuracy: 0.8441
# Epoch 85: val_loss improved from 1.16278 to 1.15078, saving model to modelbest_val_accuracy.h5
#
# Epoch 85: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0808 - accuracy: 0.8441 - val_loss: 1.1508 - val_accuracy: 0.8093
# Epoch 86/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0703 - accuracy: 0.8441
# Epoch 86: val_loss improved from 1.15078 to 1.13916, saving model to modelbest_val_accuracy.h5
#
# Epoch 86: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0703 - accuracy: 0.8441 - val_loss: 1.1392 - val_accuracy: 0.8093
# Epoch 87/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0575 - accuracy: 0.8441
# Epoch 87: val_loss improved from 1.13916 to 1.12791, saving model to modelbest_val_accuracy.h5
#
# Epoch 87: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0575 - accuracy: 0.8441 - val_loss: 1.1279 - val_accuracy: 0.8093
# Epoch 88/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0457 - accuracy: 0.8441
# Epoch 88: val_loss improved from 1.12791 to 1.11703, saving model to modelbest_val_accuracy.h5
#
# Epoch 88: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0457 - accuracy: 0.8441 - val_loss: 1.1170 - val_accuracy: 0.8093
# Epoch 89/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0335 - accuracy: 0.8441
# Epoch 89: val_loss improved from 1.11703 to 1.10649, saving model to modelbest_val_accuracy.h5
#
# Epoch 89: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0335 - accuracy: 0.8441 - val_loss: 1.1065 - val_accuracy: 0.8093
# Epoch 90/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0220 - accuracy: 0.8441
# Epoch 90: val_loss improved from 1.10649 to 1.09628, saving model to modelbest_val_accuracy.h5
#
# Epoch 90: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 1.0220 - accuracy: 0.8441 - val_loss: 1.0963 - val_accuracy: 0.8093
# Epoch 91/140
# 3/3 [==============================] - ETA: 0s - loss: 1.0104 - accuracy: 0.8441
# Epoch 91: val_loss improved from 1.09628 to 1.08638, saving model to modelbest_val_accuracy.h5
#
# Epoch 91: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 1.0104 - accuracy: 0.8441 - val_loss: 1.0864 - val_accuracy: 0.8093
# Epoch 92/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9992 - accuracy: 0.8441
# Epoch 92: val_loss improved from 1.08638 to 1.07676, saving model to modelbest_val_accuracy.h5
#
# Epoch 92: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9992 - accuracy: 0.8441 - val_loss: 1.0768 - val_accuracy: 0.8093
# Epoch 93/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.8441
# Epoch 93: val_loss improved from 1.07676 to 1.06750, saving model to modelbest_val_accuracy.h5
#
# Epoch 93: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9900 - accuracy: 0.8441 - val_loss: 1.0675 - val_accuracy: 0.8093
# Epoch 94/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9784 - accuracy: 0.8441
# Epoch 94: val_loss improved from 1.06750 to 1.05853, saving model to modelbest_val_accuracy.h5
#
# Epoch 94: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9784 - accuracy: 0.8441 - val_loss: 1.0585 - val_accuracy: 0.8093
# Epoch 95/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9690 - accuracy: 0.8441
# Epoch 95: val_loss improved from 1.05853 to 1.04984, saving model to modelbest_val_accuracy.h5
#
# Epoch 95: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9690 - accuracy: 0.8441 - val_loss: 1.0498 - val_accuracy: 0.8093
# Epoch 96/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9595 - accuracy: 0.8441
# Epoch 96: val_loss improved from 1.04984 to 1.04142, saving model to modelbest_val_accuracy.h5
#
# Epoch 96: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9595 - accuracy: 0.8441 - val_loss: 1.0414 - val_accuracy: 0.8093
# Epoch 97/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9502 - accuracy: 0.8441
# Epoch 97: val_loss improved from 1.04142 to 1.03325, saving model to modelbest_val_accuracy.h5
#
# Epoch 97: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9502 - accuracy: 0.8441 - val_loss: 1.0332 - val_accuracy: 0.8093
# Epoch 98/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9408 - accuracy: 0.8441
# Epoch 98: val_loss improved from 1.03325 to 1.02532, saving model to modelbest_val_accuracy.h5
#
# Epoch 98: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.9408 - accuracy: 0.8441 - val_loss: 1.0253 - val_accuracy: 0.8093
# Epoch 99/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9328 - accuracy: 0.8441
# Epoch 99: val_loss improved from 1.02532 to 1.01766, saving model to modelbest_val_accuracy.h5
#
# Epoch 99: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 0.9328 - accuracy: 0.8441 - val_loss: 1.0177 - val_accuracy: 0.8093
# Epoch 100/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.8441
# Epoch 100: val_loss improved from 1.01766 to 1.01024, saving model to modelbest_val_accuracy.h5
#
# Epoch 100: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9244 - accuracy: 0.8441 - val_loss: 1.0102 - val_accuracy: 0.8093
# Epoch 101/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9175 - accuracy: 0.8441
# Epoch 101: val_loss improved from 1.01024 to 1.00306, saving model to modelbest_val_accuracy.h5
#
# Epoch 101: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9175 - accuracy: 0.8441 - val_loss: 1.0031 - val_accuracy: 0.8093
# Epoch 102/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9092 - accuracy: 0.8441
# Epoch 102: val_loss improved from 1.00306 to 0.99604, saving model to modelbest_val_accuracy.h5
#
# Epoch 102: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9092 - accuracy: 0.8441 - val_loss: 0.9960 - val_accuracy: 0.8093
# Epoch 103/140
# 3/3 [==============================] - ETA: 0s - loss: 0.9005 - accuracy: 0.8441
# Epoch 103: val_loss improved from 0.99604 to 0.98925, saving model to modelbest_val_accuracy.h5
#
# Epoch 103: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.9005 - accuracy: 0.8441 - val_loss: 0.9892 - val_accuracy: 0.8093
# Epoch 104/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8930 - accuracy: 0.8441
# Epoch 104: val_loss improved from 0.98925 to 0.98268, saving model to modelbest_val_accuracy.h5
#
# Epoch 104: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8930 - accuracy: 0.8441 - val_loss: 0.9827 - val_accuracy: 0.8093
# Epoch 105/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8842 - accuracy: 0.8441
# Epoch 105: val_loss improved from 0.98268 to 0.97632, saving model to modelbest_val_accuracy.h5
#
# Epoch 105: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8842 - accuracy: 0.8441 - val_loss: 0.9763 - val_accuracy: 0.8093
# Epoch 106/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8791 - accuracy: 0.8441
# Epoch 106: val_loss improved from 0.97632 to 0.97015, saving model to modelbest_val_accuracy.h5
#
# Epoch 106: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.8791 - accuracy: 0.8441 - val_loss: 0.9701 - val_accuracy: 0.8093
# Epoch 107/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8722 - accuracy: 0.8441
# Epoch 107: val_loss improved from 0.97015 to 0.96414, saving model to modelbest_val_accuracy.h5
#
# Epoch 107: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 0.8722 - accuracy: 0.8441 - val_loss: 0.9641 - val_accuracy: 0.8093
# Epoch 108/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8659 - accuracy: 0.8441
# Epoch 108: val_loss improved from 0.96414 to 0.95831, saving model to modelbest_val_accuracy.h5
#
# Epoch 108: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 0.8659 - accuracy: 0.8441 - val_loss: 0.9583 - val_accuracy: 0.8093
# Epoch 109/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8588 - accuracy: 0.8441
# Epoch 109: val_loss improved from 0.95831 to 0.95265, saving model to modelbest_val_accuracy.h5
#
# Epoch 109: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 0.8588 - accuracy: 0.8441 - val_loss: 0.9526 - val_accuracy: 0.8093
# Epoch 110/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8534 - accuracy: 0.8441
# Epoch 110: val_loss improved from 0.95265 to 0.94719, saving model to modelbest_val_accuracy.h5
#
# Epoch 110: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8534 - accuracy: 0.8441 - val_loss: 0.9472 - val_accuracy: 0.8093
# Epoch 111/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8464 - accuracy: 0.8441
# Epoch 111: val_loss improved from 0.94719 to 0.94191, saving model to modelbest_val_accuracy.h5
#
# Epoch 111: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8464 - accuracy: 0.8441 - val_loss: 0.9419 - val_accuracy: 0.8093
# Epoch 112/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8403 - accuracy: 0.8441
# Epoch 112: val_loss improved from 0.94191 to 0.93671, saving model to modelbest_val_accuracy.h5
#
# Epoch 112: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 0.8403 - accuracy: 0.8441 - val_loss: 0.9367 - val_accuracy: 0.8093
# Epoch 113/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8355 - accuracy: 0.8441
# Epoch 113: val_loss improved from 0.93671 to 0.93165, saving model to modelbest_val_accuracy.h5
#
# Epoch 113: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8355 - accuracy: 0.8441 - val_loss: 0.9317 - val_accuracy: 0.8093
# Epoch 114/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8309 - accuracy: 0.8441
# Epoch 114: val_loss improved from 0.93165 to 0.92674, saving model to modelbest_val_accuracy.h5
#
# Epoch 114: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.8309 - accuracy: 0.8441 - val_loss: 0.9267 - val_accuracy: 0.8093
# Epoch 115/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8243 - accuracy: 0.8441
# Epoch 115: val_loss improved from 0.92674 to 0.92194, saving model to modelbest_val_accuracy.h5
#
# Epoch 115: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8243 - accuracy: 0.8441 - val_loss: 0.9219 - val_accuracy: 0.8093
# Epoch 116/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8201 - accuracy: 0.8441
# Epoch 116: val_loss improved from 0.92194 to 0.91728, saving model to modelbest_val_accuracy.h5
#
# Epoch 116: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.8201 - accuracy: 0.8441 - val_loss: 0.9173 - val_accuracy: 0.8093
# Epoch 117/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8142 - accuracy: 0.8441
# Epoch 117: val_loss improved from 0.91728 to 0.91275, saving model to modelbest_val_accuracy.h5
#
# Epoch 117: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.8142 - accuracy: 0.8441 - val_loss: 0.9127 - val_accuracy: 0.8093
# Epoch 118/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8079 - accuracy: 0.8441
# Epoch 118: val_loss improved from 0.91275 to 0.90835, saving model to modelbest_val_accuracy.h5
#
# Epoch 118: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 0.8079 - accuracy: 0.8441 - val_loss: 0.9083 - val_accuracy: 0.8093
# Epoch 119/140
# 3/3 [==============================] - ETA: 0s - loss: 0.8044 - accuracy: 0.8441
# Epoch 119: val_loss improved from 0.90835 to 0.90405, saving model to modelbest_val_accuracy.h5
#
# Epoch 119: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.8044 - accuracy: 0.8441 - val_loss: 0.9041 - val_accuracy: 0.8093
# Epoch 120/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7997 - accuracy: 0.8441
# Epoch 120: val_loss improved from 0.90405 to 0.89984, saving model to modelbest_val_accuracy.h5
#
# Epoch 120: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.7997 - accuracy: 0.8441 - val_loss: 0.8998 - val_accuracy: 0.8093
# Epoch 121/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7948 - accuracy: 0.8441
# Epoch 121: val_loss improved from 0.89984 to 0.89571, saving model to modelbest_val_accuracy.h5
#
# Epoch 121: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.7948 - accuracy: 0.8441 - val_loss: 0.8957 - val_accuracy: 0.8093
# Epoch 122/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7892 - accuracy: 0.8441
# Epoch 122: val_loss improved from 0.89571 to 0.89167, saving model to modelbest_val_accuracy.h5
#
# Epoch 122: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.7892 - accuracy: 0.8441 - val_loss: 0.8917 - val_accuracy: 0.8093
# Epoch 123/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7861 - accuracy: 0.8441
# Epoch 123: val_loss improved from 0.89167 to 0.88773, saving model to modelbest_val_accuracy.h5
#
# Epoch 123: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 0.7861 - accuracy: 0.8441 - val_loss: 0.8877 - val_accuracy: 0.8093
# Epoch 124/140
# ...
# Epoch 134/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7416 - accuracy: 0.8441
# Epoch 134: val_loss improved from 0.85361 to 0.85052, saving model to modelbest_val_accuracy.h5
#
# Epoch 134: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 53ms/step - loss: 0.7416 - accuracy: 0.8441 - val_loss: 0.8505 - val_accuracy: 0.8093
# Epoch 135/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7391 - accuracy: 0.8441
# Epoch 135: val_loss improved from 0.85052 to 0.84746, saving model to modelbest_val_accuracy.h5
#
# Epoch 135: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.7391 - accuracy: 0.8441 - val_loss: 0.8475 - val_accuracy: 0.8093
# Epoch 136/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.8441
# Epoch 136: val_loss improved from 0.84746 to 0.84464, saving model to modelbest_val_accuracy.h5
#
# Epoch 136: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 54ms/step - loss: 0.7347 - accuracy: 0.8441 - val_loss: 0.8446 - val_accuracy: 0.8093
# Epoch 137/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7316 - accuracy: 0.8441
# Epoch 137: val_loss improved from 0.84464 to 0.84203, saving model to modelbest_val_accuracy.h5
#
# Epoch 137: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 0.7316 - accuracy: 0.8441 - val_loss: 0.8420 - val_accuracy: 0.8093
# Epoch 138/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.8441
# Epoch 138: val_loss improved from 0.84203 to 0.83921, saving model to modelbest_val_accuracy.h5
#
# Epoch 138: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 55ms/step - loss: 0.7283 - accuracy: 0.8441 - val_loss: 0.8392 - val_accuracy: 0.8093
# Epoch 139/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7258 - accuracy: 0.8441
# Epoch 139: val_loss improved from 0.83921 to 0.83637, saving model to modelbest_val_accuracy.h5
#
# Epoch 139: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 57ms/step - loss: 0.7258 - accuracy: 0.8441 - val_loss: 0.8364 - val_accuracy: 0.8093
# Epoch 140/140
# 3/3 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.8441
# Epoch 140: val_loss improved from 0.83637 to 0.83350, saving model to modelbest_val_accuracy.h5
#
# Epoch 140: val_accuracy did not improve from 0.80926
# 3/3 [==============================] - 0s 56ms/step - loss: 0.7213 - accuracy: 0.8441 - val_loss: 0.8335 - val_accuracy: 0.8093
# WARNING:absl:Found untraced functions such as lstm_cell_202_layer_call_fn, lstm_cell_202_layer_call_and_return_conditional_losses, lstm_cell_203_layer_call_fn, lstm_cell_203_layer_call_and_return_conditional_losses, lstm_cell_205_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model.pkl/assets
# INFO:tensorflow:Assets written to: model.pkl/assets
# layer: 0
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_48 (Bidirecti  (None, 120, 4)           304
#  onal)
#
#  bidirectional_49 (Bidirecti  (None, 120, 4)           112
#  onal)
#
#  time_distributed_28 (TimeDi  (None, 120, 10)          50
#  stributed)
#
# =================================================================
# Total params: 466
# Trainable params: 466
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2781 - accuracy: 0.0313
# Epoch 1: val_loss improved from inf to 2.26840, saving model to modelbest_val_accuracy.h5
#
# Epoch 1: val_accuracy improved from -inf to 0.04537, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 4s 354ms/step - loss: 2.2781 - accuracy: 0.0313 - val_loss: 2.2684 - val_accuracy: 0.0454
# Epoch 2/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2688 - accuracy: 0.0582
# Epoch 2: val_loss improved from 2.26840 to 2.25850, saving model to modelbest_val_accuracy.h5
#
# Epoch 2: val_accuracy improved from 0.04537 to 0.07593, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.2688 - accuracy: 0.0582 - val_loss: 2.2585 - val_accuracy: 0.0759
# Epoch 3/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2593 - accuracy: 0.1113
# Epoch 3: val_loss improved from 2.25850 to 2.24858, saving model to modelbest_val_accuracy.h5
#
# Epoch 3: val_accuracy improved from 0.07593 to 0.13056, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.2593 - accuracy: 0.1113 - val_loss: 2.2486 - val_accuracy: 0.1306
# Epoch 4/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2499 - accuracy: 0.3284
# Epoch 4: val_loss improved from 2.24858 to 2.23855, saving model to modelbest_val_accuracy.h5
#
# Epoch 4: val_accuracy improved from 0.13056 to 0.79167, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 2.2499 - accuracy: 0.3284 - val_loss: 2.2386 - val_accuracy: 0.7917
# Epoch 5/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2404 - accuracy: 0.6087
# Epoch 5: val_loss improved from 2.23855 to 2.22840, saving model to modelbest_val_accuracy.h5
#
# Epoch 5: val_accuracy improved from 0.79167 to 0.82407, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 64ms/step - loss: 2.2404 - accuracy: 0.6087 - val_loss: 2.2284 - val_accuracy: 0.8241
# Epoch 6/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2304 - accuracy: 0.7672
# Epoch 6: val_loss improved from 2.22840 to 2.21806, saving model to modelbest_val_accuracy.h5
#
# Epoch 6: val_accuracy improved from 0.82407 to 0.84444, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 68ms/step - loss: 2.2304 - accuracy: 0.7672 - val_loss: 2.2181 - val_accuracy: 0.8444
# Epoch 7/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2206 - accuracy: 0.8003
# Epoch 7: val_loss improved from 2.21806 to 2.20751, saving model to modelbest_val_accuracy.h5
#
# Epoch 7: val_accuracy improved from 0.84444 to 0.85278, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 66ms/step - loss: 2.2206 - accuracy: 0.8003 - val_loss: 2.2075 - val_accuracy: 0.8528
# Epoch 8/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2109 - accuracy: 0.8102
# Epoch 8: val_loss improved from 2.20751 to 2.19675, saving model to modelbest_val_accuracy.h5
#
# Epoch 8: val_accuracy improved from 0.85278 to 0.86204, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 70ms/step - loss: 2.2109 - accuracy: 0.8102 - val_loss: 2.1967 - val_accuracy: 0.8620
# Epoch 9/140
# 3/3 [==============================] - ETA: 0s - loss: 2.2000 - accuracy: 0.8239
# Epoch 9: val_loss improved from 2.19675 to 2.18567, saving model to modelbest_val_accuracy.h5
#
# Epoch 9: val_accuracy improved from 0.86204 to 0.86296, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 70ms/step - loss: 2.2000 - accuracy: 0.8239 - val_loss: 2.1857 - val_accuracy: 0.8630
# Epoch 10/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1899 - accuracy: 0.8264
# Epoch 10: val_loss improved from 2.18567 to 2.17422, saving model to modelbest_val_accuracy.h5
#
# Epoch 10: val_accuracy did not improve from 0.86296
# 3/3 [==============================] - 0s 57ms/step - loss: 2.1899 - accuracy: 0.8264 - val_loss: 2.1742 - val_accuracy: 0.8630
# Epoch 11/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1788 - accuracy: 0.8311
# Epoch 11: val_loss improved from 2.17422 to 2.16247, saving model to modelbest_val_accuracy.h5
#
# Epoch 11: val_accuracy improved from 0.86296 to 0.86389, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 65ms/step - loss: 2.1788 - accuracy: 0.8311 - val_loss: 2.1625 - val_accuracy: 0.8639
# Epoch 12/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1676 - accuracy: 0.8349
# Epoch 12: val_loss improved from 2.16247 to 2.15033, saving model to modelbest_val_accuracy.h5
#
# Epoch 12: val_accuracy improved from 0.86389 to 0.86481, saving model to modelbest_val_loss.h5
# 3/3 [==============================] - 0s 70ms/step - loss: 2.1676 - accuracy: 0.8349 - val_loss: 2.1503 - val_accuracy: 0.8648
# Epoch 13/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1564 - accuracy: 0.8362
# Epoch 13: val_loss improved from 2.15033 to 2.13784, saving model to modelbest_val_accuracy.h5
#
# Epoch 13: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 57ms/step - loss: 2.1564 - accuracy: 0.8362 - val_loss: 2.1378 - val_accuracy: 0.8648
# Epoch 14/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1445 - accuracy: 0.8361
# Epoch 14: val_loss improved from 2.13784 to 2.12498, saving model to modelbest_val_accuracy.h5
#
# Epoch 14: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 55ms/step - loss: 2.1445 - accuracy: 0.8361 - val_loss: 2.1250 - val_accuracy: 0.8648
# Epoch 15/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1320 - accuracy: 0.8372
# Epoch 15: val_loss improved from 2.12498 to 2.11167, saving model to modelbest_val_accuracy.h5
#
# Epoch 15: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 56ms/step - loss: 2.1320 - accuracy: 0.8372 - val_loss: 2.1117 - val_accuracy: 0.8648
# Epoch 16/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1191 - accuracy: 0.8374
# Epoch 16: val_loss improved from 2.11167 to 2.09779, saving model to modelbest_val_accuracy.h5
#
# Epoch 16: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 55ms/step - loss: 2.1191 - accuracy: 0.8374 - val_loss: 2.0978 - val_accuracy: 0.8648
# Epoch 17/140
# 3/3 [==============================] - ETA: 0s - loss: 2.1056 - accuracy: 0.8380
# Epoch 17: val_loss improved from 2.09779 to 2.08328, saving model to modelbest_val_accuracy.h5
#
# Epoch 17: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 54ms/step - loss: 2.1056 - accuracy: 0.8380 - val_loss: 2.0833 - val_accuracy: 0.8648
# Epoch 18/140
# 3/3 [==============================] - ETA: 0s - loss: 2.0920 - accuracy: 0.8382
# Epoch 18: val_loss improved from 2.08328 to 2.06814, saving model to modelbest_val_accuracy.h5
#
# Epoch 18: val_accuracy did not improve from 0.86481
# 3/3 [==============================] - 0s 56ms/step - loss: 2.0920 - accuracy: 0.8382 - val_loss: 2.0681 - val_accuracy: 0.8648
# Epoch 19/140
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-5cd66ffdc7a9> in <module>
# ----> 1 model.train_crossValidation()
#
# ~/PycharmProjects/Phynteny/phynteny_utils/train_model.py in train_crossValidation(self, model_out, history_out, n_splits)
#     270
#     271             # use the compile function here
# --> 272             self.train_model(X_train, y_train, X_val, y_val, model_out, history_out)
#
# ~/PycharmProjects/Phynteny/phynteny_utils/train_model.py in train_model(self, X_1, y_1, X_val, y_val, model_out, history_out, epochs)
#     223         # model with the best validation set accuracy therefore maximise
#     224         model = self.generate_LSTM()
# --> 225         history = model.fit(
#     226             X_1,
#     227             y_1,
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1562                         ):
#    1563                             callbacks.on_train_batch_begin(step)
# -> 1564                             tmp_logs = self.train_function(iterator)
#    1565                             if data_handler.should_sync:
#    1566                                 context.async_wait()
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import glob

# %%
optimizer = keras.optimizers.RMSprop(lr=0.0003, decay=1e-6)X.shape
# Out:
# (10, 120, 16)
