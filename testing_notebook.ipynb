# %% [markdown]
# # Testing the functions work correctly

# %%
import pickle5
from phynteny_utils import train_model
from phynteny_utils import format_data

# %%
from importlib import reload
reload(train_model)
#reload(format_data)
# Out:
# <module 'phynteny_utils.train_model' from '/Users/susiegrigson/PycharmProjects/Phynteny/phynteny_utils/train_model.py'>

# %%
prophage_dict =pickle5.load(open('test_data/test_training_data.pkl', 'rb'))
subset_keys = list(prophage_dict.keys())[0:10]
subset_dict = dict(zip(subset_keys, [prophage_dict.get(i) for i in subset_keys]))

# %%
X, y, masked_idx = format_data.generate_dataset(subset_dict, 'all', 10, 120)
X.shape
# Out:
# (10, 120, 16)

# %%
train_model.perform_search(X,y)
# Out:
# KerasClassifier(
# 	model=<function generate_LSTM at 0x7fa72b9178b0>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=0
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# )
# (10, 1920)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-c51881ca602c> in <module>
# ----> 1 train_model.perform_search(X,y)
#
# ~/PycharmProjects/Phynteny/phynteny_utils/train_model.py in perform_search(X, y)
#     101     #print(y.shape)
#     102
# --> 103     search_result = search.fit(X, y)
#     104
#     105     # evaluate the results of the grid search
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     849                     )
#     850
# --> 851                 _warn_or_raise_about_fit_failures(out, self.error_score)
#     852
#     853                 # For callable self.scoring, the return type is only know after
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _warn_or_raise_about_fit_failures(results, error_score)
#     365                 f"Below are more details about the failures:\n{fit_errors_summary}"
#     366             )
# --> 367             raise ValueError(all_fits_failed_message)
#     368
#     369         else:
#
# ValueError:
# All the 15 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_fileql9ao1yw.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filej5ika9tg.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filean4lp6ve.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filebkve13vq.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_fileuin_5wmx.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_8" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filenvqcw9qf.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filext2s2_c4.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filemelktkna.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filepgzqv3j0.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_fileusdxkgvw.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filej5ika9tg.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_fileuin_5wmx.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_9" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_fileql9ao1yw.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filext2s2_c4.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_11" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)
#
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 1494, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 762, in fit
#     self._fit(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 931, in _fit
#     self._fit_keras_model(
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/scikeras/wrappers.py", line 526, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/var/folders/df/d2hn3bdx7dj7syrpbrxgtzkw0000gn/T/__autograph_generated_filepgzqv3j0.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_10" is incompatible with the layer: expected shape=(None, 1, 1920), found shape=(None, 1920)

# %%
model = train_model.Model('phrog_annotation_info/integer_category.pkl') #create a model object

model.parse_data(subset_dict)
#created = model.generate_LSTM(layers = 0) #create a phynteny model which has one layer
model.perform_search()
# Out:
# KerasClassifier(
# 	model=<function generate_LSTM at 0x7fa6e801cdc0>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=None
# 	validation_batch_size=None
# 	verbose=0
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=None
# )
# (10, 1920)
# (10, 1200)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/multiprocessing/queues.py", line 116, in get
#     return _ForkingPickler.loads(res)
# AttributeError: Can't get attribute 'generate_LSTM' on <module 'phynteny_utils.train_model' from '/Users/susiegrigson/PycharmProjects/Phynteny/phynteny_utils/train_model.py'>
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-66-854c99801843> in <module>
#       3 model.parse_data(subset_dict)
#       4 #created = model.generate_LSTM(layers = 0) #create a phynteny model which has one layer
# ----> 5 model.perform_search()
#
# ~/PycharmProjects/Phynteny/phynteny_utils/train_model.py in perform_search(self)
#     176         print(self.y.shape)
#     177
# --> 178         search_result = search.fit(self.X,self.y)
#     179
#     180         # evaluate the results of the grid search
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     819                     )
#     820
# --> 821                 out = parallel(
#     822                     delayed(_fit_and_score)(
#     823                         clone(base_estimator),
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# ~/opt/anaconda3/envs/phynteny/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 2.4254 - accuracy: 0.0350

# %%
optimizer = keras.optimizers.RMSprop(lr=0.0003, decay=1e-6)X.shape
# Out:
# (10, 120, 16)
