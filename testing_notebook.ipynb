# %% [markdown]
# # Testing the functions work correctly

# %%
import pickle5
from phynteny_utils import train_model
from phynteny_utils import format_data

# %%
from importlib import reload
reload(train_model)
reload(format_data)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-215-9626eac0f42b>", line 3, in <module>
#     reload(format_data)
#
#   File "/Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#
#   File "<frozen importlib._bootstrap_external>", line 779, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 916, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 846, in source_to_code
#
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#
#   File "/Users/susiegrigson/PycharmProjects/Phynteny/phynteny_utils/format_data.py", line 224
# ...

# %%
prophage_dict =pickle5.load(open('test_data/test_training_data.pkl', 'rb'))
subset_keys = list(prophage_dict.keys())
subset_dict = dict(zip(subset_keys, [prophage_dict.get(i) for i in subset_keys]))

# %%
model = train_model.Model('phrog_annotation_info/phrog_integer.pkl', features_include = 'all')
model.fit_data('test_data/test_training_data.pkl')

# %%
model.train_crossValidation()
# Out:
# /Users/susiegrigson/opt/anaconda3/envs/phynteny/lib/python3.8/site-packages/sklearn/model_selection/_split.py:700: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=10.
#   warnings.warn(
# layer: 0
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  bidirectional_46 (Bidirecti  (None, 120, 4)           304
#  onal)
#
#  bidirectional_47 (Bidirecti  (None, 120, 4)           112
#  onal)
#
#  time_distributed_27 (TimeDi  (None, 120, 10)          50
#  stributed)
#
# ...
# Total params: 466
# Trainable params: 466
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/140
# 3/3 [==============================] - ETA: 0s - loss: 2.4366 - accuracy: 0.0146
# Epoch 1: val_loss improved from inf to 2.39559, saving model to modelbest_val_accuracy.h5
#
# ...

# %%
# Out:
# 1/1 [==============================] - 0s 28ms/step - loss: 2.4254 - accuracy: 0.0350

# %%
optimizer = keras.optimizers.RMSprop(lr=0.0003, decay=1e-6)X.shape
# Out:
# (10, 120, 16)
